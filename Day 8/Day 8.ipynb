# %%
import numpy as np

with open('example.txt', 'r') as file:
    jukeboxes = file.readlines()

jukebox_coordinates = [list(map(int,s.strip().split(","))) for s in jukeboxes]
jukebox_coordinates
# Out:
# [[162, 817, 812],
#  [57, 618, 57],
#  [906, 360, 560],
#  [592, 479, 940],
#  [352, 342, 300],
#  [466, 668, 158],
#  [542, 29, 236],
#  [431, 825, 988],
#  [739, 650, 466],
#  [52, 470, 668],
#  [216, 146, 977],
#  [819, 987, 18],
#  [117, 168, 530],
#  [805, 96, 715],
#  [346, 949, 466],
#  [970, 615, 88],
#  [941, 993, 340],
#  [862, 61, 35],
#  [984, 92, 344],
#  [425, 690, 689]]

# %%
""" jukebox_pairs[d] = (x, y)
    d: euclidean distance between jukebox x and y
    x: 3d coordinates of jukebox x
    y: 3d coordinates of jukebox x
"""
jukebox_pairs = dict()

for i in range(len(jukebox_coordinates)):
    for j in range(len(jukebox_coordinates)):
        if i == j:
            continue
        jukebox_0 = np.array(jukebox_coordinates[i])
        jukebox_1 = np.array(jukebox_coordinates[j])
        distance = np.linalg.norm(jukebox_0 - jukebox_1)
        jukebox_pairs[distance] = (i, j)


keys = list(jukebox_pairs.keys())
keys.sort()
sorted_jukebox_pairs = {i: jukebox_pairs[i] for i in keys}
sorted_jukebox_pairs
# Out:
# {316.90219311326956: (19, 0),
#  321.560258738545: (7, 0),
#  322.36935338211043: (13, 2),
#  328.11888089532425: (19, 7),
#  333.6555109690233: (18, 17),
#  338.33858780813046: (12, 9),
#  344.3893145845266: (16, 11),
#  347.59890678769403: (8, 2),
#  350.786259708102: (19, 14),
#  352.936254867646: (18, 2),
#  367.9823365326113: (19, 3),
#  371.70552861102294: (6, 4),
#  372.02284876066415: (12, 4),
#  373.41130138226936: (5, 4),
#  379.242666376029: (17, 6),
#  384.6309919910251: (7, 3),
#  387.2014979309868: (19, 8),
#  391.46519640959144: (9, 0),
#  407.53527454687895: (15, 11),
#  411.9441709746601: (18, 13),
#  411.96723170660067: (8, 5),
#  413.5166260260886: (14, 0),
#  417.52724462003675: (16, 8),
#  424.24285497813634: (5, 1),
#  433.55507147304826: (19, 9),
#  433.84905209070126: (14, 5),
#  444.3759669469086: (15, 8),
#  455.22412062631304: (16, 15),
#  458.360120429341: (12, 10),
#  459.34409760004536: (18, 6),
#  471.4339826529267: (4, 1),
#  476.8154779366962: (10, 9),
#  491.7397685768358: (9, 4),
#  492.62866339668057: (13, 3),
#  493.81170500505556: (14, 8),
#  495.95362686444787: (11, 5),
#  503.62088916167886: (10, 3),
#  507.10649769057386: (3, 2),
#  511.5906566777779: (15, 5),
#  521.7173564297051: (8, 4),
#  524.9057058177211: (8, 3),
#  527.0237186313344: (19, 4),
#  533.0347080631805: (19, 5),
#  535.1467088565527: (12, 6),
#  540.2823335997579: (15, 2),
#  543.2172677667749: (14, 7),
#  550.5442761486128: (13, 6),
#  561.7187908553532: (3, 0),
#  566.2799660945105: (11, 8),
#  566.9118097199952: (17, 15),
#  582.4611575032278: (18, 15),
#  589.0950687282996: (6, 2),
#  597.2277622482063: (14, 9),
#  597.412755136681: (19, 2),
#  600.3024237832128: (14, 1),
#  603.633995066547: (16, 5),
#  604.7024061470237: (9, 3),
#  605.773885208004: (17, 2),
#  609.7843881241959: (16, 14),
#  609.9721305108948: (9, 7),
#  610.9607188682428: (13, 8),
#  612.2417823049975: (4, 2),
#  621.5086483710423: (18, 8),
#  626.6011490573569: (19, 12),
#  628.6891123599962: (9, 1),
#  629.3178846973921: (14, 4),
#  630.8510125219742: (8, 7),
#  639.7546404677344: (17, 4),
#  646.5794614739939: (13, 10),
#  648.2136993307068: (6, 5),
#  650.0469213833721: (19, 10),
#  652.5925221759746: (14, 11),
#  655.6134531871658: (12, 1),
#  661.7779083650345: (13, 4),
#  670.8710755428349: (5, 2),
#  671.0543942185313: (16, 2),
#  681.0726833459113: (18, 4),
#  683.2817866736973: (17, 13),
#  686.0757975617563: (9, 5),
#  690.9052033383451: (8, 6),
#  692.7236101072347: (19, 16),
#  693.0959529531247: (10, 0),
#  693.2055972076394: (8, 0),
#  697.1147681694887: (4, 3),
#  700.31849897029: (12, 3),
#  705.628797598284: (19, 13),
#  708.0939203241333: (15, 4),
#  709.0486584149215: (12, 0),
#  711.4014337910769: (14, 3),
#  712.3110275715237: (10, 7),
#  714.2723570179655: (12, 5),
#  716.0677342263091: (13, 12),
#  717.8028977372549: (10, 4),
#  723.7879523727927: (4, 0),
#  734.8686957545546: (19, 1),
#  735.1149569965231: (17, 5),
#  736.432617419951: (5, 0),
#  738.3583140995976: (9, 8),
#  740.1425538367592: (17, 8),
#  740.597056434874: (15, 6),
#  783.7008357785514: (6, 1),
#  787.814064357828: (1, 0),
#  788.1655917381829: (9, 6),
#  789.4960417886844: (12, 8),
#  790.5909182377445: (7, 2),
#  795.8825290204579: (8, 1),
#  796.6781031257229: (18, 5),
#  802.3814554188051: (15, 14),
#  809.8265246335168: (19, 6),
#  811.5719315008374: (18, 3),
#  812.5792269065214: (12, 2),
#  814.3224177191735: (5, 3),
#  814.770519839789: (19, 15),
#  816.393287576521: (14, 12),
#  817.9523213488669: (10, 6),
#  818.142408141761: (14, 2),
#  830.4908187331152: (15, 13),
#  832.8781423473664: (19, 11),
#  833.3438666000968: (11, 2),
#  834.1372788696115: (10, 2),
#  837.0280759926754: (6, 3),
#  841.5628318788799: (16, 7),
#  842.0771936111321: (13, 9),
#  844.3186602225489: (7, 4),
#  844.7709748801742: (11, 4),
#  845.4430791011303: (7, 5),
#  847.5411494434945: (11, 1),
#  860.2377578321008: (12, 7),
#  863.6237606735933: (13, 7),
#  863.711178577654: (16, 3),
#  867.3834215616529: (13, 5),
#  867.801820694103: (9, 2),
#  878.8185250664667: (16, 4),
#  888.0686910369039: (10, 8),
#  888.3186365263311: (19, 18),
#  889.9780896179411: (18, 12),
#  900.8323928456392: (17, 12),
#  902.034367416231: (18, 16),
#  908.7843528582565: (2, 0),
#  913.5310613219455: (15, 1),
#  927.1537089393538: (17, 11),
#  927.6858304404568: (16, 0),
#  941.9575361978904: (15, 3),
#  960.640411392317: (14, 10),
#  966.7088496543311: (18, 11),
#  968.3573720481504: (14, 6),
#  970.9268767523124: (13, 0),
#  979.1618865131546: (17, 1),
#  981.6975094192711: (16, 13),
#  983.8140068122633: (17, 16),
#  996.7090849390307: (18, 10),
#  1000.1454894164149: (14, 13),
#  1001.0844120252797: (16, 1),
#  1002.8683861803602: (10, 5),
#  1007.1375278481088: (19, 17),
#  1019.9872548223335: (2, 1),
#  1020.7923393129477: (11, 6),
#  1024.444239575781: (7, 1),
#  1032.7870061150072: (17, 3),
#  1041.746130302388: (3, 1),
#  1044.5022738127477: (11, 0),
#  1046.1668127024486: (10, 1),
#  1047.4349621814235: (6, 0),
#  1048.4812826178634: (16, 6),
#  1056.6380648074344: (18, 9),
#  1057.2076428024914: (11, 7),
#  1059.614080691645: (15, 12),
#  1069.869618224576: (15, 7),
#  1075.3497105593137: (18, 14),
#  1076.8830020016103: (11, 3),
#  1082.328046388894: (16, 9),
#  1095.5131217835776: (15, 9),
#  1100.6548051046705: (7, 6),
#  1103.5596948058587: (15, 0),
#  1103.7998006885125: (18, 1),
#  1106.376970114617: (17, 9),
#  1113.8047405178343: (17, 14),
#  1121.531987952194: (18, 7),
#  1124.700849114999: (13, 1),
#  1130.5211187766463: (11, 9),
#  1131.3204674184942: (13, 11),
#  1145.384215012587: (17, 10),
#  1181.3979007938012: (16, 12),
#  1191.7772442868675: (18, 0),
#  1194.0305691229182: (12, 11),
#  1256.502288099787: (15, 10),
#  1284.057241714714: (16, 10),
#  1290.4514713851117: (17, 0),
#  1295.2474667027918: (17, 7),
#  1410.8759690348404: (11, 10)}

# %%
# https://www.geeksforgeeks.org/dsa/introduction-to-disjoint-set-data-structure-or-union-find-algorithm/
class UnionFind:
    def __init__(self, size):
      
        # Initialize the parent array with each 
        # element as its own representative
        self.parent = list(range(size))
    
    def find(self, i):
      
        # If i itself is root or representative
        if self.parent[i] == i:
            return i
          
        # Else recursively find the representative 
        # of the parent
        return self.find(self.parent[i])
    
    def unite(self, i, j):
      
        # Representative of set containing i
        irep = self.find(i)
        
        # Representative of set containing j
        jrep = self.find(j)
        
        # Make the representative of i's set
        # be the representative of j's set
        self.parent[irep] = jrep

# %%
def connect_juke_boxes(uf, pairs, connection_count):
    """
        Parameters
        ----------
        uf : UnionFind
            An instance of the Disjoint Set Union datastructure
        pairs : dictionary(distance, (x,y))
            A dictionary sorted by its key 'distance'. 'x' and 'y' are jukeboxes denoted by an integer
    """
    jukebox_pair = list(pairs.values())
    for i in range(connection_count):
        x, y = jukebox_pair[i]
        uf.unite(x, y)

# %%
union_find = UnionFind(len(jukeboxes))
connect_juke_boxes(union_find, sorted_jukebox_pairs, 10)
union_find.parent
# Out:
# [14, 1, 2, 3, 4, 5, 6, 0, 2, 9, 10, 11, 9, 2, 14, 15, 11, 2, 17, 0]

# %%
circuits = dict.fromkeys(set(union_find.parent),0)
for rep in union_find.parent:
    circuits[rep] += 1

circuits
# Out:
# {0: 2,
#  1: 1,
#  2: 4,
#  3: 1,
#  4: 1,
#  5: 1,
#  6: 1,
#  9: 2,
#  10: 1,
#  11: 2,
#  14: 2,
#  15: 1,
#  17: 1}
