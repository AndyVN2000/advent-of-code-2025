# %% [markdown]
# # Part One

# %%
import re
import numpy as np

# %%
with open('example.txt', 'r') as file:
    for line in file.readlines()[:-1]:
        row = re.split("\s *", line.strip())
        print(row)
        row_str_to_int(row)
        print(row)
# Out:
# ['123', '328', '51', '64']
# [123, 328, 51, 64]
# ['45', '64', '387', '23']
# [45, 64, 387, 23]
# ['6', '98', '215', '314']
# [6, 98, 215, 314]
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\AVN\AppData\Local\Temp\ipykernel_18456\3468710904.py:3: SyntaxWarning: invalid escape sequence '\s'
#   row = re.split("\s *", line.strip())

# %%
def row_str_to_int(row):
    for i in range(0, len(row)):
        row[i] = int(row[i])

# %%
with open('input.txt', 'r') as file:
    operands = []
    lines = file.readlines()
    for line in lines[:-1]:
        row = re.split("\s *", line.strip())
        row_str_to_int(row)
        operands.append(row)
        

    operators = lines[-1]

# %% [markdown]
# # Part Two
